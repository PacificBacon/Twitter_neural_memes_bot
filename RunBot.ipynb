# %%
from getpass import getpass
password = getpass('GitHub password')
url = 'https://PacificBacon:' + password + '@github.com/PacificBacon/Wild_Rift_News_Bot'
# Out:
# GitHub password··········

# %%
import os
os.environ['GITHUB_PATH'] = url
# !git clone $GITHUB_PATH
# %cd ./Wild_Rift_News_Bot/
# Out:
# Cloning into 'Wild_Rift_News_Bot'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.
# /content/Wild_Rift_News_Bot

# %%
# %pip install -r requirements.txt

# %%
token = getpass('Telegram token')
os.environ['TG_TOKEN'] = token
# Out:
# Telegram token··········

# %%
# !python3 bot.py --tg_token $TG_TOKEN
# Out:
# Bot started
# покажи одну новость
# Input message: покажи одну новость
# Score to one: 0.8529307246208191
# Score to several: 0.7890637516975403
# Mean score: 0.8209972381591797
# Find num: 1
# One article.
# /content/Wild_Rift_News_Bot/tg_utils.py:16: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 16 of the file /content/Wild_Rift_News_Bot/tg_utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   news_soup = BeautifulSoup(news_result.text)
# 0
# https://wildrift.leagueoflegends.com/en-us/news/dev/wild-rift-real-talk-july-2021/
# ...
